# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\morep\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\morep\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\morep\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\morep\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\morep\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\morep\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\morep\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\morep\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\morep\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\morep\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\morep\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\morep\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
text= "the process of planning, organizing, and controlling how much time to spend on specific activities to increase efficiency, productivity, and focus"

# %%
from nltk.tokenize import sent_tokenize
tokenized_text= sent_tokenize(text)
print(tokenized_text)
# Out:
# ['the process of planning, organizing, and controlling how much time to spend on specific activities to increase efficiency, productivity, and focus']

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['the', 'process', 'of', 'planning', ',', 'organizing', ',', 'and', 'controlling', 'how', 'much', 'time', 'to', 'spend', 'on', 'specific', 'activities', 'to', 'increase', 'efficiency', ',', 'productivity', ',', 'and', 'focus']

# %%
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {'am', "doesn't", "we'd", 'weren', 'does', 'here', 'when', 'whom', 'too', 'shouldn', "you've", "i'm", 'own', 'been', "won't", 'an', 'him', "it'll", "he's", "mustn't", 'its', 'so', 'were', 'as', "mightn't", 'is', 'they', "they're", 'i', "you're", "should've", 'before', 'if', 'once', "wasn't", 'just', 'by', 'about', 'aren', 'won', 'd', 'o', 'over', 'from', 'some', 'this', 'he', 'being', 'm', 'above', 'into', 'there', 'will', 'during', 'after', 'how', "it's", 'mightn', 'what', 'between', 'her', 'but', 'further', 'themselves', 'to', 'did', 'wasn', 'should', 'ain', "i'll", 'most', 've', 'ours', 'only', 'my', 'yourself', 'doing', 'on', 'same', 'll', "shan't", 'few', 'we', "they'll", 'yourselves', "we're", 'she', 'didn', 'theirs', "it'd", "weren't", "he'll", 'himself', "i've", 'not', 'against', 'all', 'with', 'in', 'under', 's', 'isn', 'itself', 'very', 'herself', "she'd", 'while', 'out', 'hadn', 'ourselves', 'any', 'off', 'because', "aren't", 'has', "needn't", 'no', "haven't", "they'd", "hadn't", 'y', 'your', 'needn', "wouldn't", 'be', 'both', 'each', "shouldn't", 'why', 'you', "that'll", 'wouldn', 'other', 'these', 'that', 'then', 'mustn', 'was', 'down', "hasn't", "you'd", 'again', "isn't", 'a', 'ma', 'more', 'now', 'nor', 're', 'hasn', "she'll", 'their', "you'll", 'or', 'couldn', "she's", 'hers', 'me', 'through', "couldn't", 'and', 'of', 'below', 'such', 'those', 'yours', 'his', 'don', 'are', 'them', 't', 'doesn', 'at', 'where', 'until', 'can', 'do', 'shan', 'our', 'it', "they've", 'up', 'which', 'the', "he'd", 'than', "we've", 'haven', 'having', 'who', 'myself', 'have', "i'd", "we'll", 'for', 'had', "didn't", "don't"}

# %%
text= "How to remove stop words with NLTK library in Python?"
import re
text= re.sub('[^a-zA-Z]', ' ',text)
tokens = word_tokenize(text.lower())
filtered_text=[]
for w in tokens:
    if w not in stop_words:
        filtered_text.append(w)
print("Tokenized Sentence:",tokens)
print("Filterd Sentence:",filtered_text)
# Out:
# Tokenized Sentence: ['how', 'to', 'remove', 'stop', 'words', 'with', 'nltk', 'library', 'in', 'python']
# Filterd Sentence: ['remove', 'stop', 'words', 'nltk', 'library', 'python']

# %%
from nltk.stem import PorterStemmer
e_words= ["wait", "waiting", "waited","waits"]
ps =PorterStemmer()
for w in e_words:
    rootWord=ps.stem(w)
print(rootWord)
# Out:
# wait

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer() 
text = "studies studying cries cry" 
tokenization = nltk.word_tokenize(text)
for w in tokenization:
    print("Lemma for {} is {}".format(w,wordnet_lemmatizer.lemmatize(w)))
# Out:
# Lemma for studies is study
# Lemma for studying is studying
# Lemma for cries is cry
# Lemma for cry is cry

# %%
import nltk 
from nltk.tokenize import word_tokenize
data="The pink sweater fit her perfectly"
words=word_tokenize(data)
for word in words:
        print(nltk.pos_tag([word]))
# Out:
# [('The', 'DT')]
# [('pink', 'NN')]
# [('sweater', 'NN')]
# [('fit', 'NN')]
# [('her', 'PRP$')]
# [('perfectly', 'RB')]
